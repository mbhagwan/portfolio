# %% [markdown]
# # Investigating Netflix Movies

# %% [markdown]
# <figure>
# <img src="redpopcorn.jpg">
# <figcaption style="font-size: 11px;">Fun fact: Netflix was started in 1997 as a DVD rental service</figcaption>
# </figure>

# %% [markdown]
# You work for a production company that specializes in nostalgic styles. You want to do some research on
# movies released in the 1990's. Delve into Netflix data and perform exploratory data analysis to
# better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the
# column names and descriptions.
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Change the default console output settings in NumPy and pandas to improve readability
pd.options.display.max_columns = 20
pd.options.display.max_rows = 20
pd.options.display.max_colwidth = 80
np.set_printoptions(precision=4, suppress=True)

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("files/netflix_data.csv")

# %% [markdown]
# Perform exploratory data analysis on the netflix_data.csv data to understand more about movies from
# the 1990s decade.
#
# * What was the most frequent movie duration in the 1990s? Save an approximate answer as an
# integer called duration (use 1990 as the decade's start year).
#
# * A movie is considered short if it is less than 90 minutes. Count the number of short action movies
# released in the 1990s and save this integer as short_movie_count.

# %%
# Check for null values and field datatypes
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4812 non-null   object
#  1   type          4812 non-null   object
#  2   title         4812 non-null   object
#  3   director      4812 non-null   object
#  4   cast          4812 non-null   object
#  5   country       4812 non-null   object
#  6   date_added    4812 non-null   object
#  7   release_year  4812 non-null   int64
#  8   duration      4812 non-null   int64
#  9   description   4812 non-null   object
#  10  genre         4812 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 413.7+ KB

# %% [markdown]
# **1. Filter the data for movies released in the 1990s**

# %%
# Filter DataFrame for rows where release year is between 1990 and 1999
netflix_1990s = netflix_df[(netflix_df["release_year"] >= 1990) 
    & (netflix_df["release_year"] <= 1999)]

netflix_1990s.head(3)
# Out:
#     show_id   type                   title            director  \
# 6        s8  Movie                     187      Kevin Reynolds
# 118    s167  Movie       A Dangerous Woman  Stephen Gyllenhaal
# 145    s211  Movie  A Night at the Roxbury    John Fortenberry
#
#                                                                                 cast  \
# 6        Samuel L. Jackson, John Heard, Kelly Rowan, Clifton Collins Jr., Tony Plana
# 118  Debra Winger, Barbara Hershey, Gabriel Byrne, Laurie Metcalf, John Terry, Ma...
# 145  Will Ferrell, Chris Kattan, Dan Hedaya, Molly Shannon, Richard Grieco, Loni ...
#
#            country        date_added  release_year  duration  \
# 6    United States  November 1, 2019          1997       119
# 118  United States     April 1, 2018          1993       101
# 145  United States  December 1, 2019          1998        82
#
#                                                                          description  \
# ...

# %% [markdown]
# **2. Find the most frequent movie duration**

# %%
# Visualize the data to view the movie distributions
plt.hist(netflix_1990s["duration"], bins=15)
plt.xlabel("Duration in minutes")
plt.ylabel("Number of movies")
plt.title("Distribution of durations of movies released in the 1990s")
plt.show()

# %%
# The most frequent movie duration in the 1990s
duration = 100

print("The most frequent movie duration:", duration, "minutes")
# Out:
# The most frequent movie duration: 100 minutes

# %% [markdown]
# **3. Count the number of short action movies from the 1990s**

# %%
# Filter netflix_1990s for movies in the action genre
netflix_1990s_action = netflix_1990s[netflix_1990s["genre"] == "Action"]

netflix_1990s_action.head(3)
# Out:
#     show_id   type                                  title           director  \
# 352    s508  Movie                        Andaz Apna Apna  Rajkumar Santoshi
# 431    s628  Movie  Austin Powers: The Spy Who Shagged Me          Jay Roach
# 468    s688  Movie                               Bad Boys        Michael Bay
#
#                                                                                 cast  \
# 352  Aamir Khan, Salman Khan, Raveena Tandon, Karisma Kapoor, Paresh Rawal, Mehmo...
# 431  Mike Myers, Heather Graham, Michael York, Robert Wagner, Rob Lowe, Seth Gree...
# 468  Will Smith, Martin Lawrence, Téa Leoni, Tchéky Karyo, Theresa Randle, Joe Pa...
#
#            country        date_added  release_year  duration  \
# 352          India      May 11, 2020          1994       160
# 431  United States  December 1, 2019          1999        95
# 468  United States   October 1, 2019          1995       119
#
# ...

# %%
# Number of action movies less than 90 minutes in the 1990s
short_movie_count = 0

for label, row in netflix_1990s_action.iterrows():
    if row["duration"] < 90:
        short_movie_count += 1

print("Number of action movies less than 90 minutes:", short_movie_count)
# Out:
# Number of action movies less than 90 minutes: 7

# %% [markdown]
# <div style="text-align: center; font-size: 18px; font-weight: bold; color: #007BFF;">
# <span>[ End of notebook ]</span>
# </div>
